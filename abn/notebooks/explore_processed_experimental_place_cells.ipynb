# %%
import os
import sys
import warnings

sys.path.append(os.path.dirname(os.getcwd()))
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

expt_id = "15_hd"
timestep_ns = 1000000

data_path = f"../data/expt{expt_id}_place_cells_timestep{timestep_ns}.npy"
times_path = f"../data/expt{expt_id}_times__timestep{timestep_ns}.txt"
labels_path = f"../data/expt{expt_id}_labels_timestep{timestep_ns}.txt"

print(f"Loading experiment {expt_id}...")
expt = np.load(data_path)

print(expt.shape)
# Out:
# Loading experiment 15_hd...
# (1758, 32)

# %%
labels = pd.read_csv(labels_path)
labels
# Out:
#       Unnamed: 0         times      angles  velocities  gains   radius2  \
# 0              0  1.049947e+11  122.659747   13.345347    1.0  0.262980
# 1              1  1.049957e+11  134.143228   22.008615    1.0  0.233389
# 2              2  1.049967e+11  148.847090    1.032394    1.0  0.103806
# 3              3  1.049977e+11  165.580578   29.712668    1.0  0.286712
# 4              4  1.049987e+11  196.114146   30.834155    1.0  0.156696
# ...          ...           ...         ...         ...    ...       ...
# 1753        1753  1.067477e+11   55.871178   22.085845    1.0  0.014234
# 1754        1754  1.067487e+11   93.163834   42.199397    1.0  0.004935
# 1755        1755  1.067497e+11  140.145358   48.987204    1.0  0.168106
# 1756        1756  1.067507e+11  182.708405   27.654601    1.0  0.114497
# 1757        1757  1.067517e+11  192.757311    8.491377    1.0  0.199837
#
#              x         y         z   rx_head   ry_head   rz_head  \
# 0    -0.491371 -0.146750  0.020216 -0.136440  2.233160  0.975501
# 1    -0.450560 -0.174311  0.013856 -0.015624  2.084198  0.886889
# 2    -0.285114 -0.150055  0.009171 -0.227618  1.269406  0.493156
# 3    -0.402505 -0.353131  0.012810 -0.640683  2.350172  0.932957
# 4    -0.232667 -0.320253  0.018711 -0.768527  1.726125  0.515612
# ...        ...       ...       ...       ...       ...       ...
# 1753  0.077470  0.090734  0.004667  0.275292  0.181742  0.048865
# 1754  0.044457  0.054397  0.007994  0.200472  0.105934  0.020539
# 1755  0.225113  0.342681  0.023416  1.423237  0.353568  0.201989
# 1756  0.004555  0.338344  0.017615  1.019215  0.721519  0.218220
# 1757 -0.303318  0.328383  0.008598  1.006961  1.340800  0.500253
#
#       angles_tracked  angles_head   success
# 0          -2.851372     2.440743  0.644444
# 1          -2.772452     2.265104  0.644444
# 2          -2.657130     1.380726  0.422222
# 3          -2.421442     2.608485  0.711111
# 4          -2.199094     1.958571  0.555556
# ...              ...          ...       ...
# 1753        0.864090     0.333472  0.155556
# 1754        0.885613     0.227668  0.111111
# 1755        0.989574     1.480342  0.577778
# 1756        1.557333     1.267679  0.466667
# 1757        2.316536     1.749848  0.400000
#
# [1758 rows x 15 columns]
