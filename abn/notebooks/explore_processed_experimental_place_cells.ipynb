# %%
import os
import sys
import warnings

sys.path.append(os.path.dirname(os.getcwd()))
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

expt_id = "15_hd"
timestep_ns = 1000000

data_path = f"../data/expt{expt_id}_place_cells_timestep{timestep_ns}.npy"
times_path = f"../data/expt{expt_id}_times__timestep{timestep_ns}.txt"
labels_path = f"../data/expt{expt_id}_labels_timestep{timestep_ns}.txt"

print(f"Loading experiment {expt_id}...")
expt = np.load(data_path)

print(expt.shape)
# Out:
# Loading experiment 15_hd...
# (1758, 32)

# %%
labels = pd.read_csv(labels_path)
labels
# Out:
#       Unnamed: 0         times      angles  velocities  gains   radius2  \
# 0              0  1.049947e+11  122.659747   13.345347    1.0  0.370425
# 1              1  1.049957e+11  134.143228   22.008615    1.0  0.350161
# 2              2  1.049967e+11  148.847090    1.032394    1.0  0.236144
# 3              3  1.049977e+11  165.580578   29.712668    1.0  0.391206
# 4              4  1.049987e+11  196.114146   30.834155    1.0  0.287121
# ...          ...           ...         ...         ...    ...       ...
# 1753        1753  1.067477e+11   55.871178   22.085845    1.0  0.081905
# 1754        1754  1.067487e+11   93.163834   42.199397    1.0  0.044441
# 1755        1755  1.067497e+11  140.145358   48.987204    1.0  0.283955
# 1756        1756  1.067507e+11  182.708405   27.654601    1.0  0.246505
# 1757        1757  1.067517e+11  192.757311    8.491377    1.0  0.333172
#
#              z        qz  angles_tracked  angles_head   success
# 0     0.020216  0.282035       -2.851372     2.162585  0.644444
# 1     0.013856  0.259770       -2.772452     2.042338  0.644444
# 2     0.009171  0.157961       -2.657130     1.355086  0.422222
# 3     0.012810  0.260616       -2.421442     2.168190  0.711111
# 4     0.018711  0.143514       -2.199094     1.588149  0.555556
# ...        ...       ...             ...          ...       ...
# 1753  0.004667  0.021542        0.864090     0.445705  0.155556
# 1754  0.007994  0.009499        0.885613     0.283823  0.111111
# 1755  0.023416  0.075343        0.989574     1.464512  0.577778
# 1756  0.017615  0.080680        1.557333     1.279754  0.466667
# 1757  0.008598  0.168826        2.316536     1.722153  0.400000
#
# [1758 rows x 11 columns]
