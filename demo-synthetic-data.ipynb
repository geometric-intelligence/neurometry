# %%
# %load_ext autoreload
# %autoreload 2
from neurometry.neural_simulators.population_manifold.hypersphere import PopulationHypersphere
from neurometry.neural_simulators.population_manifold.hypertorus import PopulationHypertorus
from neurometry.stimuli.hypersphere import StimuliHypersphere
from neurometry.stimuli.hypertorus import StimuliHypertorus
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
s2_stimuli = StimuliHypersphere(intrinsic_dim=2)
t2_stimuli = StimuliHypertorus(intrinsic_dim=2)
s2_data_random = s2_stimuli.sample(1000, method="random")
t2_data_random = t2_stimuli.sample(1000, method="random")
s2_population = PopulationHypersphere(intrinsic_dim=2, n_neurons=1000)
t2_population = PopulationHypertorus(intrinsic_dim=2, n_neurons=1000)
t2_response = t2_population(t2_data_random)
s2_response = s2_population(s2_data_random)

# %%
plt.imshow(s2_response)

# %%
plt.imshow(t2_response)
