# %%
import matplotlib.pyplot as plt

import numpy as np
import torch


model = torch.load("results/2022-05-14 16:29:32.463829_model.pt")

# %%
dataset = np.load("data/place_cells_expt34.npy")
data_dim = dataset.shape[-1]

dataset = np.log(dataset.astype(np.float32) + 1)
dataset = (dataset - np.min(dataset)) / (np.max(dataset) - np.min(dataset))
dataset_torch = torch.tensor(dataset)

# %%
latents_torch, _ = model.encode(dataset_torch)

# %%
latents = latents_torch.cpu().detach().numpy()

# %%
angles = np.load("data/rat_angles_expt34_b.npy")

# %%
plt.figure(figsize=(5, 5))
plt.scatter(latents[:, 0], latents[:, 1], c=angles, cmap="twilight")
plt.colorbar();

# %%
model = torch.load("results/2022-05-14 16:37:33.824376_model_latent3.pt")
dataset = np.load("data/place_cells_expt34.npy")
data_dim = dataset.shape[-1]

dataset = np.log(dataset.astype(np.float32) + 1)
dataset = (dataset - np.min(dataset)) / (np.max(dataset) - np.min(dataset))
dataset_torch = torch.tensor(dataset)

latents_torch, _ = model.encode(dataset_torch)
latents = latents_torch.cpu().detach().numpy()
angles = np.load("data/rat_angles_expt34_b.npy")

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')

ax.scatter(latents[:, 0], latents[:, 1], latents[:,2], s=20, c=angles, cmap="twilight");
# Out:
# <img src="data:image/png;base64,..." width="576">
